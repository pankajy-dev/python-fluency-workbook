# %% [markdown]
# # Day 13 — Useful stdlib Modules
# **Concepts:** collections, itertools, os, pathlib, datetime

# %% [markdown]
# ## Assignment 1
# Use `Counter` from `collections` to find the 3 most common words in a sentence.

# %% [markdown]
# ## Assignment 2
# Use `defaultdict` to group a list of `(name, city)` tuples by city.

# %% [markdown]
# ## Assignment 3
# Use `itertools.chain` to iterate over multiple lists as one.

# %% [markdown]
# ## Assignment 4
# Use `pathlib.Path` to list all `.txt` files in the current directory.

# %% [markdown]
# ## Assignment 5
# Use `datetime` to print how many days until New Year's Day 2027.
