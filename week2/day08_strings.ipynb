# %% [markdown]
# # Day 8 — Strings Deep-dive
# **Concepts:** .split(), .join(), .strip(), .replace(), slicing, .upper/.lower, in

# %% [markdown]
# ## Assignment 1
# Reverse a string using slicing.

# %% [markdown]
# ## Assignment 2
# Check if a string is a palindrome (ignore case and spaces).

# %% [markdown]
# ## Assignment 3
# Given `"  hello world  "`, strip whitespace and title-case it.

# %% [markdown]
# ## Assignment 4
# Split `"a,b,,c,d"` on commas, filter out empty strings, and rejoin with `" | "`.

# %% [markdown]
# ## Assignment 5
# Count how many times `"the"` appears in a sentence (case-insensitive).

# %% [markdown]
# ## Assignment 6
# Given a list of words, join them into a sentence with proper capitalization.
