# %% [markdown]
# # Day 9 — File I/O
# **Concepts:** open(), modes (r/w/a), with, reading lines, writing

# %% [markdown]
# ## Assignment 1
# Write a list of 5 names to a file, one per line.

# %% [markdown]
# ## Assignment 2
# Read the file back and print each name with its line number.

# %% [markdown]
# ## Assignment 3
# Append two more names to the same file without overwriting it.

# %% [markdown]
# ## Assignment 4
# Read a file and count the total number of words across all lines.

# %% [markdown]
# ## Assignment 5
# Copy the contents of one file to another, converting all text to uppercase.
