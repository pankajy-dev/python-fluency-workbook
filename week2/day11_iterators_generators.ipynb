# %% [markdown]
# # Day 11 — Iterators & Generators
# **Concepts:** iter/next, enumerate, zip, yield, generator expressions

# %% [markdown]
# ## Assignment 1
# Use `enumerate` to print a list with 1-based index numbers.

# %% [markdown]
# ## Assignment 2
# Use `zip` to pair two lists into a dict.

# %% [markdown]
# ## Assignment 3
# Write a generator `countdown(n)` that yields from n down to 0.

# %% [markdown]
# ## Assignment 4
# Write a generator that yields only prime numbers up to n.

# %% [markdown]
# ## Assignment 5
# Use a generator expression to compute the sum of squares of even numbers 1–100.
