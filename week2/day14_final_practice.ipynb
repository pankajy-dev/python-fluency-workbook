# %% [markdown]
# # Day 14 — Final Practice
# Mixed problems — no hints, no notes.

# %% [markdown]
# ## Assignment 1 — Anagram checker
# Given two strings, return `True` if they are anagrams.

# %% [markdown]
# ## Assignment 2 — Most frequent item
# Return the most common element in a list.

# %% [markdown]
# ## Assignment 3 — File word stats
# Read a text file, print the top 5 most frequent words (ignore punctuation).

# %% [markdown]
# ## Assignment 4 — Matrix transpose
# Given a 2D list, return its transpose using comprehensions.

# %% [markdown]
# ## Assignment 5 — Fibonacci generator
# Yields Fibonacci numbers indefinitely; print the first 15.

# %% [markdown]
# ## Assignment 6 — Class + decorator
# `BankAccount` class, decorate `withdraw()` to log every withdrawal.

# %% [markdown]
# ## Assignment 7 — Chain of filters
# From a list of dicts (name/age/city),
# filter adults from a specific city, sort by name, print names.
