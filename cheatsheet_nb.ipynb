# %% [markdown]
# # Reference code

# %%
num = 28
fname = 'Pankaj'
lname = "Yadav"
weight = 65.5
married = True
print(type(num))
print(type(fname))
print(type(weight))
print(type(married))

# %%
num1 = "12"
num2 = "5"
sum = int(num1) + int(num2)
sum

# %% [markdown]
# ## Practice code during reading from w3schools

# %% [markdown]
# ### Print without a new line
# using end=""

# %%
print("Hello World", end="")

# %% [markdown]
# ### multiple values in a single line

# %%
a,b, c = "apple", 'mango', 'banana'
print(a,b,c)

# %% [markdown]
# ### one value to multiple variable

# %%
a=b=c= "Orange"
print(a,b,c)

# %%
# Unpack a collection
fruits = ['apple', 'banana', 'mango']
x,y,z = fruits
print(x,y,z)

# %%
# Global variables

x = 'awesome'
def myFunc():
    print('Python is ' + x)
myFunc()

# %%
# Global variables

x = 'awesome'
def myFunc():
    x = 'fantastic'
    print('Python is ' + x)
print(x)
myFunc()

# %% [markdown]
# ## Use of Global variable inside function:
# 1. use `global` to declare a golbal variable from inside a function
# 2. use `global` keyword to change global variable from inside a function

# %%
def myFunc():
    global newG
    newG = 'new global variable from inside a func'
myFunc()
print(newG)

# %%
# Global variables

x = 'awesome'
def myFunc():
    global x 
    x = "great"
    print('Python is ' + x)
myFunc()
print('Python is ' + x)

# %% [markdown]
# ### Scientific number

# %%
print(3.5e4)

# %%
print(3.5E4)

# %% [markdown]
# ### String operations

# %%
a = 'Hello World'
for ch in a:
    print(ch, end= ', ')

# %%
print(len(a))

# %%
print('ello' in a)

# %%
print('hi' not in a)

# %% [markdown]
# ### Slicing in strings

# %%
print(a[2:7])

# %%
print(a[-5: -2])

# %% [markdown]
# ### String formatting

# %%
# we cannot combine strings and numbers
age = 36
#This will produce an error:
txt = "My name is John, I am " + age
print(txt)

# %% [markdown]
# ### Above oprtation can be done using f-string

# %%
age = 36
#This will produce an error:
txt = f"My name is John, I am {age}"
print(txt)

# %% [markdown]
# ### Whatever we place inside {} is called placeholder
#
# We can modify the placeholder by using the : like .2f

# %%
price = 29
txt = f'The price is {price:.2f}'
print(txt)

# %%
## you can also perform math operations inside placeholder
txt = f'mul of 2 and 3 is {2*3}'
txt

# %% [markdown]
# ### \ is a escape character

# %%
"pankaj".capitalize()

# %%
### Repeated data types 
List : []
Tuple : ()
Map : {}
Set : {}

# %% [markdown]
# ### Loops in python

# %%
fruits = ['apple', 'banana', 'cranberry']
for f in range(len(fruits)):
    print(fruits[f])

# %%
for fruit in fruits:
    print(fruit)

# %% [markdown]
# ### List comprehension

# %%
[print(x) for x in fruits]

# %%
[print(x) for x in fruits if len(x) < 7]

# %%
[print(x) if len(x) < 7 else print("Too long") for x in fruits]

# %% [markdown]
# ### Join lists
#
# #### Three ways:
# - plus operator : To join two lists
# - append() : To add single element to the list
# - extend() : To add entire list to existing list
#
# Method	  Description
# append()  Adds an element at the end of the list
# clear()	  Removes all the elements from the list
# copy()	  Returns a copy of the list
# count()	  Returns the number of elements with the specified value
# extend()  Add the elements of a list (or any iterable), to the end of the current list
# index()	  Returns the index of the first element with the specified value
# insert()  Adds an element at the specified position
# pop()	  Removes the element at the specified position
# remove()  Removes the item with the specified value
# reverse() Reverses the order of the list
# sort()	  Sorts the list

# %% [markdown]
# ### Tuples : ()
# - Tuples are unchangeable
# - Since tuples are indexed they allow duplicate value
# - To create a tuple with one item, you have to end it with comma
#       E.g tup = ("apple",)

# %%
### Unpacking
fruits = ("apple","banana","cherry", "date","fig","grapes")
a,b,*c = fruits
print(a,b,c )
# Out:
# apple banana ['cherry', 'date', 'fig', 'grapes']

# %%
### Set :  True and 1 , False and 0 are considered duplicates in set
newSet = {'apple', "mango", 'apple'}
newSet
# Out:
# {'apple', 'mango'}

# %% [markdown]
# ### Several ways to join set
# The `union()` and `update()` methods joins all items from both sets. Operator = |
#
# The `intersection()` method keeps ONLY the duplicates. = Operator = &
#
# The `difference()` method keeps the items from the first set that are not in the other set(s). Operator = -
#
# The `symmetric_difference()` method keeps all items EXCEPT the duplicates. Operator = ^
#
# Method	                   Shortcut	   Description
# copy()	 	                           Returns a shallow copy
# difference()	             -	       Returns a new frozenset with the difference
# intersection()	             &	       Returns a new frozenset with the intersection
# isdisjoint()	 	                   Returns True if there is NO intersection between two frozensets
# issubset()	                <= / <	   Returns True if this frozenset is a (proper) subset of another
# issuperset()               >= / >	   Returns True if this frozenset is a (proper) superset of another
# symmetric_difference()	      ^        Returns a new frozenset with the symmetric differences
# union()     	              |	       Returns a new frozenset containing the union

# %% [markdown]
# ### Dictionary
#
# - Used to store key value pairs
# - .keys()
# - .values()
# - .items()
#
# - `del` keyword to remove element or entire dictionary

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
del thisdict["model"]
print(thisdict)
# Out:
# {'brand': 'Ford', 'year': 1964}

# %%
## This will result in error as del will delete the dict
del thisdict
print(thisdict)

# %% [markdown]
# ### Positional arguments and keyword arguments

# %%
def postionalArgumentFunc(name, age):
    print(f"Age is : {age} and name is : {name}")
postionalArgumentFunc('Pankaj', 33)
# Out:
# Age is : 33 and name is : Pankaj

# %%
def strictPositionalArgumentFunc(name, age, /):
    print('No keyword argument allowed')
strictPositionalArgumentFunc('Pankaj',33)
# Out:
# No keyword argument allowed
