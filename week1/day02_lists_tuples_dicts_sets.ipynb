# %% [markdown]
# # Day 2 — Lists, Tuples, Dicts, Sets
# **Concepts:** creation, indexing, slicing, common methods, iteration

# %% [markdown]
# ## Assignment 1
# Create a list of 5 fruits. Print the last two using slicing. Remove one item by value.

# %% [markdown]
# ## Assignment 2
# Swap the first and last elements of a list without using a temp variable.

# %% [markdown]
# ## Assignment 3
# Given `scores = [10, 20, 30, 40, 50]`, print the sum, max, and reversed list.

# %% [markdown]
# ## Assignment 4
# Create a dict of 3 people with their ages.
# Add a new person, update an age, delete one entry.

# %% [markdown]
# ## Assignment 5
# Given `a = [1, 2, 3, 4]` and `b = [3, 4, 5, 6]`,
# find their intersection and union using sets.

# %% [markdown]
# ## Assignment 6
# Iterate over a dict and print each key-value pair as `"name: age"`.
